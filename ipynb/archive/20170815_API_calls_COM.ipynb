# %%
import requests

# %% [markdown]
# ## CRUD
#
# | | SQL | RESTful API |
# |:-:|:-:|:-:|
# | create | `INSERT` | `POST` |
# | read | `SELECT` | `GET` |
# | update | `UPDATE` | `PUT` |
# | delete | `DELETE` | `DELETE` |

# %% [markdown]
# ![](http://interactive.blockdiag.com/image?compression=deflate&encoding=base64&src=eJxLyslPzk7JTExXqOZSUFAPcnV0UUgrys9VKM_MzixIBcqoK-jaKRSlFpfmlBSDmOqefsGuQSEKJfkKBfnFJelAKXVrrloAaBAXgg)

# %% [markdown]
# ## Read results from wikipedia

# %%
response = requests.get('https://google.com')

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'https://www.google.com/'

# %%
response.text[:50]
# Out:
# '<!doctype html><html itemscope="" itemtype="http:/'

# %% [markdown]
# ## Query Wikipedia

# %%
requests.get('https://www.wikidata.org/w/api.php?action=wbgetentities&ids=Q39246&format=json')
# Out:
# <Response [200]>

# %%
response = requests.get('https://www.wikidata.org/w/api.php?action=wbgetentities&ids=Q39246&format=json')

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
response_json = response.json()

# %%
type(response_json)
# Out:
# dict

# %%
response_json.keys()
# Out:
# dict_keys(['entities', 'success'])

# %%
response_json['success']
# Out:
# 1

# %%
response_json['entities'].keys()
# Out:
# dict_keys(['Q39246'])

# %%
# !pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.6/site-packages (from wikipedia)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from wikipedia)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement already satisfied: idna<2.6,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia)
# Building wheels for collected packages: wikipedia
#   Running setup.py bdist_wheel for wikipedia ... done
#   Stored in directory: /home/jovyan/.cache/pip/wheels/bf/87/25/df698dd7b66a42c1c5f3bd36f8155d4518d210f5e2c128b440
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
import wikipedia
results = wikipedia.search(query='Machine Learning', results = 10)
page = wikipedia.WikipediaPage( results[0], preload = True)
page.content
# Out:
# 'Machine learning is the subfield of computer science that, according to Arthur Samuel, gives "computers the ability to learn without being explicitly programmed." Samuel, an American pioneer in the field of computer gaming and artificial intelligence, coined the term "machine learning" in 1959 while at IBM. Evolved from the study of pattern recognition and computational learning theory in artificial intelligence, machine learning explores the study and construction of algorithms that can learn from and make predictions on data – such algorithms overcome following strictly static program instructions by making data-driven predictions or decisions, through building a model from sample inputs. Machine learning is employed in a range of computing tasks where designing and programming explicit algorithms with good performance is difficult or infeasible; example applications include email filtering, detection of network intruders or malicious insiders working towards a data breach, optical character recognition (OCR), learning to rank, and computer vision.\nMachine learning is closely related to (and often overlaps with) computational statistics, which also focuses on prediction-making through the use of computers. It has strong ties to mathematical optimization, which delivers methods, theory and application domains to the field. Machine learning is sometimes conflated with data mining, where the latter subfield focuses more on exploratory data analysis and is known as unsupervised learning. Machine learning can also be unsupervised and be used to learn and establish baseline behavioral profiles for various entities and then used to find meaningful anomalies.\nWithin the field of data analytics, machine learning is a method used to devise complex models and algorithms that lend themselves to prediction; in commercial use, this is known as predictive analytics. These analytical models allow researchers, data scientists, engineers, and analysts to "produce reliable, repeatable decisions and results" and uncover "hidden insights" through learning from historical relationships and trends in the data.\nAs of 2016, machine learning is a buzzword, and according to the Gartner hype cycle of 2016, at its peak of inflated expectations. Effective machine learning is difficult because finding patterns is hard and often not enough training data is available; as a result, machine-learning programs often fail to deliver.\n\n\n== Overview ==\nTom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the Machine Learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P, improves with experience E." This definition of the tasks in which machine learning is concerned offers a fundamentally operational rather than defining the field in cognitive terms. This follows Alan Turing\'s proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?" is replaced with the question "Can machines do what we (as thinking entities) can do?". In Turing\'s proposal the various characteristics that could be possessed by a thinking machine and the various implications in constructing one are exposed.\n\n\n=== Types of problems and tasks ===\n\nMachine learning tasks are typically classified into three broad categories, depending on the nature of the learning "signal" or "feedback" available to a learning system. These are\nSupervised learning: The computer is presented with example inputs and their desired outputs, given by a "teacher", and the goal is to learn a general rule that maps inputs to outputs.\nUnsupervised learning: No labels are given to the learning algorithm, leaving it on its own to find structure in its input. Unsupervised learning can be a goal in itself (discovering hidden patterns in data) or a means towards an end (feature learning).\nReinforce ...

# %%
response_wiki = wikipedia.requests.get('https://www.wikidata.org/w/api.php?action=wbgetentities&ids=Q39246&format=json')

# %%
response_wiki.json()
# Out:
# {'entities': {'Q39246': {'aliases': {'am': [{'language': 'am',
#       'value': 'ሪቻርድ ፌይንማን'}],
#     'ar': [{'language': 'ar', 'value': 'ريتشارد فينمان'}],
#     'be': [{'language': 'be', 'value': 'Рычард Фейнман'},
#      {'language': 'be', 'value': 'Рычард Файнман'}],
#     'bg': [{'language': 'bg', 'value': 'Ричард Филипс Фейнман'},
#      {'language': 'bg', 'value': 'Ричард Фейнман'},
#      {'language': 'bg', 'value': 'Фейнмън'},
#      {'language': 'bg', 'value': 'Фейнман'},
#      {'language': 'bg', 'value': 'Ричард Филипс Файнмън'},
#      {'language': 'bg', 'value': 'Ричард Файнмън'},
#      {'language': 'bg', 'value': 'Ричард Фейнмън'},
#      {'language': 'bg', 'value': 'Файнмън'},
#      {'language': 'bg', 'value': 'Ричард Филипс Фейнмън'}],
#     'bn': [{'language': 'bn', 'value': 'আর পি ফাইনম্যান'},
#      {'language': 'bn', 'value': 'রিচার্ড ফিলিপ্\u200cস ফাইনম্যান'}],
#     'bs': [{'language': 'bs', 'value': 'Richard P. Feynman'}],
#     'ca': [{'language': 'ca', 'value': 'Richard Phillips Feynman'},
#      {'language': 'ca', 'value': 'Feynman'},
#      {'language': 'ca', 'value': 'Richard P. Feynman'}],
#     'cs': [{'language': 'cs', 'value': 'Richard P. Feynman'},
#      {'language': 'cs', 'value': 'Feynman'}],
#     'de': [{'language': 'de', 'value': 'Ofey'},
#      {'language': 'de', 'value': 'Feynman'},
#      {'language': 'de', 'value': 'Richard P. Feynman'},
#      {'language': 'de', 'value': 'Richard Phillips Feynman'}],
#     'el': [{'language': 'el', 'value': 'Ρίτσαρντ Φέινμαν'},
#      {'language': 'el', 'value': 'Ρίτσαρντ Φάινμαν'},
#      {'language': 'el', 'value': 'Richard Feynman'}],
#     'en': [{'language': 'en', 'value': 'Richard Phillips Feynman'},
#      {'language': 'en', 'value': 'Richard P. Feynman'}],
#     'eo': [{'language': 'eo', 'value': 'Richard Phillips FEYNMAN'}],
#     'es': [{'language': 'es', 'value': 'Richard Phillips Feynman'},
#      {'language': 'es', 'value': 'Feynman'},
#      {'language': 'es', 'value': 'Richard P. Feynman'},
#      {'language': 'es', 'value': 'Richard P Feynman'}],
#     'et': [{'language': 'et', 'value': 'Richard Phillips Feynman'}],
#     'fa': [{'language': 'fa', 'value': 'فاینمن'}],
#     'fi': [{'language': 'fi', 'value': 'Feynman'},
#      {'language': 'fi', 'value': 'Richard Feynmann'},
#      {'language': 'fi', 'value': 'Richard P. Feynman'},
#      {'language': 'fi', 'value': 'Richard Phillips Feynman'}],
#     'fr': [{'language': 'fr', 'value': 'Richard P. Feynman'},
#      {'language': 'fr', 'value': 'Richard Phillips Feynman'},
#      {'language': 'fr', 'value': 'Feynman'}],
#     'ga': [{'language': 'ga', 'value': 'Richard P. Feynman'}],
#     'he': [{'language': 'he', 'value': 'דיק פיינמן'},
#      {'language': 'he', 'value': "ריצ'ארד פיינמן"},
#      {'language': 'he', 'value': 'פיינמן'},
#      {'language': 'he', 'value': "ריצ'רד פיליפס פיינמן"}],
#     'hi': [{'language': 'hi', 'value': 'Richard Feynman'},
#      {'language': 'hi', 'value': 'रिचार्ड फैनमन'},
#      {'language': 'hi', 'value': 'रिच्हर्ड फेइन्मन'}],
#     'hu': [{'language': 'hu', 'value': 'Richard Phillips Feynman'},
#      {'language': 'hu', 'value': 'Richard P. Feynman'},
#      {'language': 'hu', 'value': 'Feynman'}],
#     'hy': [{'language': 'hy', 'value': 'Ռիչարդ Ֆայնման'}],
#     'id': [{'language': 'id', 'value': 'Richard Phillips Feynman'},
#      {'language': 'id', 'value': 'Richard P. Feynman'},
#      {'language': 'id',
#       'value': 'Richard Phillips Feynman - Tokoh Ilmuwan Penemu Elektrodinamika Kuantum'}],
#     'io': [{'language': 'io', 'value': 'Richard Phillips Feynman'},
#      {'language': 'io', 'value': 'Richard P. Feynman'}],
#     'is': [{'language': 'is', 'value': 'Feynman'}],
#     'it': [{'language': 'it', 'value': 'Feynman'},
#      {'language': 'it', 'value': 'Richard P. Feynman'},
#      {'language': 'it', 'value': 'Richard Phillips Feynman'},
#      {'language': 'it', 'value': 'Dick Feynman'}],
#     'ja': [{'language': 'ja', 'value': 'Feynman'},
#      {'language': 'ja', 'value': 'ファインマン'},
#      {'language': 'ja', 'value': 'リチャード・ファインマン'}],
#     'jv': [{'language': 'jv', 'value': 'Richard Phillips Feynman'}],
#     'ka': [{'language': 'ka', 'value': 'ფაინმანი'},
#      {'language': 'ka', 'value': 'ფეინმანი'}],
#     'ko': [{'language': 'ko', 'value': '페인만'},
#      {'language': 'ko', 'value': '파인만'},
#      {'language': 'ko', 'value': '리차드 파인만'},
#      {'language': 'ko', 'value': '파인먼'},
#      {'language': 'ko', 'value': '리처드 파인먼'}],
#     'ku': [{'language': 'ku', 'value': 'Richard P. Feynman'}],
#     'lt': [{'language': 'lt', 'value': 'Ričardas Feinmanas'},
#      {'language': 'lt', 'value': 'Richard P. Feynman'},
#      {'language': 'lt', 'value': 'Ričardas Fainmanas'}],
#     'lv': [{'language': 'lv', 'value': 'Fainmens'},
#      {'language': 'lv', 'value': 'Feynman'},
#      {'language': 'lv', 'value': 'Feinmans'},
#      {'language': 'lv', 'value': 'Ričards Fīnmans'},
#      {'language': 'lv', 'value': 'Richard Feynman'},
#      {'language': 'lv', 'value': 'Ričards Feinmans'}],
#     'ml': [{'language': 'ml', 'value': 'റിച്ചാർഡ് ഫെയ്ന്മാൻ'},
#      {'language': 'ml', 'value': 'Richard Feynman'},
#      {'language': 'ml', 'value': 'ഫെയ്ൻമാൻ'}],
#     'mr': [{'language': 'mr', 'value': 'रिचर्ड फिलिप्स फाइनमन'}],
#     'nb': [{'language': 'nb', 'value': 'Richard P Feynman'},
#      {'language': 'nb', 'value': 'Richard Phillips Feynman'}],
#     'nl': [{'language': 'nl', 'value': 'Feynman'},
#      {'language': 'nl', 'value': 'Richard Phillips Feynman'},
#      {'language': 'nl', 'value': 'Richard P. Feynman'}],
#     'pl': [{'language': 'pl', 'value': 'Richard P. Feynman'}],
#     'pt': [{'language': 'pt', 'value': 'Richard philips feynman'},
#      {'language': 'pt', 'value': 'Richard Phillips Feynman'},
#      {'language': 'pt', 'value': 'Feynman'},
#      {'language': 'pt', 'value': 'Richard P. Feynman'}],
#     'ro': [{'language': 'ro', 'value': 'Richard P. Feynman'},
#      {'language': 'ro', 'value': 'R. P. Feynman'}],
#     'ru': [{'language': 'ru', 'value': 'Ричард Фейнман'},
#      {'language': 'ru', 'value': 'Фейнман Р. Ф.'},
#      {'language': 'ru', 'value': 'Фейнман Р.'},
#      {'language': 'ru', 'value': 'Фейнман, Ричард'},
#      {'language': 'ru', 'value': 'Р. Фейнман'},
#      {'language': 'ru', 'value': 'Фейнман'},
#      {'language': 'ru', 'value': 'Ричард Фейман'},
#      {'language': 'ru', 'value': 'Фейнман Ричард Филлипс'},
#      {'language': 'ru', 'value': 'Фейнман, Ричард Филлипс'}],
#     'sh': [{'language': 'sh', 'value': 'Ričard Fejnmen'}],
#     'sk': [{'language': 'sk', 'value': 'Richard Phillips Feynman'}],
#     'sl': [{'language': 'sl', 'value': 'Richard Feynman'},
#      {'language': 'sl', 'value': 'Richard P. Feynman'}],
#     'sq': [{'language': 'sq', 'value': 'Richard P. Feynman'},
#      {'language': 'sq', 'value': 'Ricard Fajman'}],
#     'sr': [{'language': 'sr', 'value': 'Ричард Фајман'},
#      {'language': 'sr', 'value': 'Ричард Филип Фејнман'},
#      {'language': 'sr', 'value': 'Ричард Фајнман'},
#      {'language': 'sr', 'value': 'Ричард Фејнман'}],
#     'sv': [{'language': 'sv', 'value': 'Feynman'},
#      {'language': 'sv', 'value': 'Richard P. Feynman'},
#      {'language': 'sv', 'value': 'Richard P Feynman'},
#      {'language': 'sv', 'value': 'Feynman, Richard P'}],
#     'sw': [{'language': 'sw', 'value': 'Richard Phillips Feynman'}],
#     'th': [{'language': 'th', 'value': 'Feynman'},
#      {'language': 'th', 'value': 'ริชาร์ด ฟายน์แมน'},
#      {'language': 'th', 'value': 'ริชาร์ด ไฟยน์แมน'},
#      {'language': 'th', 'value': 'ไฟน์แมน'}],
#     'tr': [{'language': 'tr', 'value': 'Richard P. Feynman'},
#      {'language': 'tr', 'value': 'Richard Phillips Feynman'}],
#     'uk': [{'language': 'uk', 'value': 'Філіпс Фейнман Річард'},
#      {'language': 'uk', 'value': 'Фейнман Річард Філіпс'},
#      {'language': 'uk', 'value': 'Ричард Фейнман'},
#      {'language': 'uk', 'value': 'Фейнман Річард'},
#      {'language': 'uk', 'value': 'Фейнман'},
#      {'language': 'uk', 'value': 'Річард Філіпс'},
#      {'language': 'uk', 'value': 'Річард Фейнман'},
#      {'language': 'uk', 'value': 'Філіпс Річард'}],
#     'vi': [{'language': 'vi', 'value': 'Richard Fâyman'},
#      {'language': 'vi', 'value': 'Feynman'},
#      {'language': 'vi', 'value': 'Richard Phillips Feynman'},
#      {'language': 'vi', 'value': 'Richard P. Feynman'},
#      {'language': 'vi', 'value': 'Richơt Fâyman'},
#      {'language': 'vi', 'value': 'Fâyman'}],
#     'zh': [{'language': 'zh', 'value': '里查德·费曼'},
#      {'language': 'zh', 'value': 'Richard Feynman'},
#      {'language': 'zh', 'value': '费曼'},
#      {'language': 'zh', 'value': '理查德·菲利普·費曼'},
#      {'language': 'zh', 'value': '理查德·费曼'},
#      {'language': 'zh', 'value': '理查得·费曼'},
#      {'language': 'zh', 'value': '理查·費因曼'},
#      {'language': 'zh', 'value': '費因曼'},
#      {'language': 'zh', 'value': '理查·費曼'},
#      {'language': 'zh', 'value': '理查德·费因曼'},
#      {'language': 'zh', 'value': '费恩曼'},
#      {'language': 'zh', 'value': '费因曼'},
#      {'language': 'zh', 'value': '理察·費曼'},
#      {'language': 'zh', 'value': '李察·费因曼'}]},
#    'claims': {'P1003': [{'id': 'Q39246$CDC4DF2A-3662-4B7C-8B2D-437F78E4011A',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': 'RUNLRAUTH7720218'},
#        'property': 'P1003',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$E72F5567-E687-4BB5-9229-3B2F8CB7FA87',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': 'RUNLRAUTH7720217'},
#        'property': 'P1003',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1005': [{'id': 'Q39246$A5332F4E-068D-499D-B692-6DD196E9E823',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '36293'},
#        'property': 'P1005',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1006': [{'id': 'Q39246$89B89FFF-9A06-4C9A-82E7-9AD53DA7CFEA',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '070781613'},
#        'property': 'P1006',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '2f2bf65c5e73428c06ae52811efbe861b325164b',
#         'snaks': {'P248': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q54919',
#              'numeric-id': 54919}},
#            'property': 'P248',
#            'snaktype': 'value'}],
#          'P813': [{'datatype': 'time',
#            'datavalue': {'type': 'time',
#             'value': {'after': 0,
#              'before': 0,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#              'precision': 11,
#              'time': '+2014-12-16T00:00:00Z',
#              'timezone': 0}},
#            'property': 'P813',
#            'snaktype': 'value'}],
#          'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://viaf.org/viaf/44298691'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P248', 'P813', 'P854']}],
#       'type': 'statement'}],
#     'P101': [{'id': 'Q39246$038c3dff-45b4-5968-980a-a18085c1be79',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q234881',
#          'numeric-id': 234881}},
#        'property': 'P101',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$d165d590-4386-c600-320e-16b0411c0068',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q18334', 'numeric-id': 18334}},
#        'property': 'P101',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P106': [{'id': 'q39246$A8BA102C-ACB5-4111-A215-F4E8B8896A28',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q169470',
#          'numeric-id': 169470}},
#        'property': 'P106',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'id': 'Q328', 'numeric-id': 328}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']},
#        {'hash': '288ab581e7d2d02995a26dfa8b091d96e78457fc',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q206855',
#              'numeric-id': 206855}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'},
#      {'id': 'Q39246$2ec978e7-473d-195b-db11-1564f18a3916',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q16745601',
#          'numeric-id': 16745601}},
#        'property': 'P106',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$D4C3032D-FA7E-4191-892F-16950B870775',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q81096', 'numeric-id': 81096}},
#        'property': 'P106',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$DA0AEFD9-B526-4C8E-9895-44939FF2DC9C',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q36180', 'numeric-id': 36180}},
#        'property': 'P106',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$3F783C40-C0DD-4FE6-86D5-A8F2C455017C',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q1622272',
#          'numeric-id': 1622272}},
#        'property': 'P106',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q48183',
#              'numeric-id': 48183}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'},
#      {'id': 'Q39246$CEEC2E4F-EB45-4510-8F2E-19050DCB5302',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q4351403',
#          'numeric-id': 4351403}},
#        'property': 'P106',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$578E56CE-1780-4229-AF79-5012C879F3FA',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q19350898',
#          'numeric-id': 19350898}},
#        'property': 'P106',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P108': [{'id': 'Q39246$E1E55ECD-9A13-49BC-B6FD-99995E4C0FC7',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q49115', 'numeric-id': 49115}},
#        'property': 'P108',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$F836086E-E613-419A-96D5-028EB736F1B1',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q161562',
#          'numeric-id': 161562}},
#        'property': 'P108',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P109': [{'id': 'Q39246$7acdfd47-4604-e17a-58e9-2826bcca65d7',
#       'mainsnak': {'datatype': 'commonsMedia',
#        'datavalue': {'type': 'string',
#         'value': 'Richard Feynman signature.svg'},
#        'property': 'P109',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1153': [{'id': 'Q39246$96AF99D3-0C31-4B9C-9EC6-1B2F7361369F',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '6508146004'},
#        'property': 'P1153',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1196': [{'id': 'Q39246$4DDF7539-6BCA-4767-A06D-BFA88249BD4F',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q3739104',
#          'numeric-id': 3739104}},
#        'property': 'P1196',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1207': [{'id': 'Q39246$E7767904-733B-4A9E-915E-6096C0B8FE40',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': 'n93080602'},
#        'property': 'P1207',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1220': [{'id': 'Q39246$43ddc845-4aaa-b3b7-3de9-5c28bd3249c7',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '92116'},
#        'property': 'P1220',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1263': [{'id': 'Q39246$BA7F074E-8D44-4647-B7C6-1DB24D3D5832',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '584/000026506'},
#        'property': 'P1263',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1273': [{'id': 'Q39246$2900CB6C-9718-478F-B62A-B31DDB067ED3',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': 'a11135888'},
#        'property': 'P1273',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'd882c526adf59a8f2271964734f5c0182acbdcae',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'https://viaf.org/viaf/44298691/'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'}],
#     'P1296': [{'id': 'Q39246$CCC1DEFC-1F7E-42FD-98E8-9CDA776238CB',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '0026949'},
#        'property': 'P1296',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1303': [{'id': 'Q39246$8f5c8869-4faa-8e01-ec01-e2089a6f1ce4',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q243998',
#          'numeric-id': 243998}},
#        'property': 'P1303',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1309': [{'id': 'Q39246$8D5AE0E3-1A98-4560-A928-005A0B408B2F',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '001017169'},
#        'property': 'P1309',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1343': [{'id': 'Q39246$0507F410-726E-4ABC-AB06-6EBE79A1C31F',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q17378135',
#          'numeric-id': 17378135}},
#        'property': 'P1343',
#        'snaktype': 'value'},
#       'qualifiers': {'P958': [{'datatype': 'string',
#          'datavalue': {'type': 'string', 'value': 'Фейнман Ричард Филлипс'},
#          'hash': '23f11e4f682052218f78849a527e7d84563e22be',
#          'property': 'P958',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P958'],
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$61EECB56-AACF-46DA-9ECF-6871819E4DD1',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q2657718',
#          'numeric-id': 2657718}},
#        'property': 'P1343',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$94e24da5-4256-cc42-60ed-fcaedf6d3320',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q1186818',
#          'numeric-id': 1186818}},
#        'property': 'P1343',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1344': [{'id': 'Q39246$6566E141-579F-4D7D-ABAC-2CC9A527C435',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q127050',
#          'numeric-id': 127050}},
#        'property': 'P1344',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P135': [{'id': 'Q39246$3C065970-8EAA-429E-BA4E-13AF02743FF1',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q7066', 'numeric-id': 7066}},
#        'property': 'P135',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P140': [{'id': 'Q39246$6D1CC2E8-56F0-4D00-86E2-41A0A3988DDF',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q7066', 'numeric-id': 7066}},
#        'property': 'P140',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1411': [{'id': 'Q39246$784D7CE1-A482-419F-89A6-B508D12A1A97',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q38104', 'numeric-id': 38104}},
#        'property': 'P1411',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1956-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': '541d389b6a794fdd13c299aa2dc9495ed63e6c57',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'references': [{'hash': 'b2981c5b69de0cb9e94790a434f39f81db7f09ca',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://www.nobelprize.org/nomination/archive/show_people.php?id=10683'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'},
#      {'id': 'Q39246$A936CA13-3F6F-4AD0-BD7F-4D256DA86A31',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q38104', 'numeric-id': 38104}},
#        'property': 'P1411',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1957-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': '133ea362ca17b897c342eb89757a0cf4d87ab0b5',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'references': [{'hash': 'b2981c5b69de0cb9e94790a434f39f81db7f09ca',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://www.nobelprize.org/nomination/archive/show_people.php?id=10683'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'},
#      {'id': 'Q39246$1186CAF4-AD63-4AE7-BD05-8A8BC2FEDBDB',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q38104', 'numeric-id': 38104}},
#        'property': 'P1411',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1960-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': '104ed548fc8e9ca1c3cbc6b10433e20df72ce53d',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'references': [{'hash': 'b2981c5b69de0cb9e94790a434f39f81db7f09ca',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://www.nobelprize.org/nomination/archive/show_people.php?id=10683'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'},
#      {'id': 'Q39246$59CEDC9B-96E0-48DF-9755-DDD221BD5A8B',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q38104', 'numeric-id': 38104}},
#        'property': 'P1411',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1962-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': 'ac45bb0d862a664f58e27a283554efd1210d0dab',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'references': [{'hash': 'b2981c5b69de0cb9e94790a434f39f81db7f09ca',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://www.nobelprize.org/nomination/archive/show_people.php?id=10683'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'},
#      {'id': 'Q39246$77169C93-A100-45BD-BD01-C605CAD555FC',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q38104', 'numeric-id': 38104}},
#        'property': 'P1411',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1963-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': '3827c07d63138f958ff3d110090c53f8f718fcc2',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'references': [{'hash': 'b2981c5b69de0cb9e94790a434f39f81db7f09ca',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://www.nobelprize.org/nomination/archive/show_people.php?id=10683'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'},
#      {'id': 'Q39246$B39562E8-A155-4B7E-8BEA-741EF32ABC80',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q38104', 'numeric-id': 38104}},
#        'property': 'P1411',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1964-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': '3abb02b5511ac7efda133b7b29c0056d4a59a7ab',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'references': [{'hash': 'b2981c5b69de0cb9e94790a434f39f81db7f09ca',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://www.nobelprize.org/nomination/archive/show_people.php?id=10683'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'},
#      {'id': 'Q39246$F4DA5485-A799-4A9B-95A0-E63D9215433A',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q38104', 'numeric-id': 38104}},
#        'property': 'P1411',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1965-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': '866d1ba57547885004724e093d4798a4b0dfaf43',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'references': [{'hash': 'b2981c5b69de0cb9e94790a434f39f81db7f09ca',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://www.nobelprize.org/nomination/archive/show_people.php?id=10683'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'}],
#     'P1412': [{'id': 'Q39246$550D68D8-F38D-4F2F-A6EF-603792FECB8C',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q1860', 'numeric-id': 1860}},
#        'property': 'P1412',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '66a5ae7d70099abcfe32a8aa68e33f77cb43cd09',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q20666306',
#              'numeric-id': 20666306}},
#            'property': 'P143',
#            'snaktype': 'value'}],
#          'P813': [{'datatype': 'time',
#            'datavalue': {'type': 'time',
#             'value': {'after': 0,
#              'before': 0,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#              'precision': 11,
#              'time': '+2015-10-10T00:00:00Z',
#              'timezone': 0}},
#            'property': 'P813',
#            'snaktype': 'value'}],
#          'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://data.bnf.fr/ark:/12148/cb119027159'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143', 'P813', 'P854']}],
#       'type': 'statement'}],
#     'P1477': [{'id': 'Q39246$2eba1aad-4d13-5064-1c85-b5448310e2be',
#       'mainsnak': {'datatype': 'monolingualtext',
#        'datavalue': {'type': 'monolingualtext',
#         'value': {'language': 'en', 'text': 'Richard Phillips Feynman'}},
#        'property': 'P1477',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1556': [{'id': 'Q39246$9cbae414-41d4-a1ee-28d2-a1bc7dcd1f0f',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': 'feynman.richard-p'},
#        'property': 'P1556',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1559': [{'id': 'Q39246$d404e302-43e6-c2e6-37de-4971be18f14c',
#       'mainsnak': {'datatype': 'monolingualtext',
#        'datavalue': {'type': 'monolingualtext',
#         'value': {'language': 'en', 'text': 'Richard Phillips Feynman'}},
#        'property': 'P1559',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '288ab581e7d2d02995a26dfa8b091d96e78457fc',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q206855',
#              'numeric-id': 206855}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P1563': [{'id': 'Q39246$b1a6b21e-4614-b7ef-67da-e6104515d631',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': 'Feynman'},
#        'property': 'P1563',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P166': [{'id': 'q39246$1A0578A1-4B3F-41F6-BF2C-269E35B2F2C3',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q38104', 'numeric-id': 38104}},
#        'property': 'P166',
#        'snaktype': 'value'},
#       'qualifiers': {'P1706': [{'datatype': 'wikibase-item',
#          'datavalue': {'type': 'wikibase-entityid',
#           'value': {'entity-type': 'item',
#            'id': 'Q186465',
#            'numeric-id': 186465}},
#          'hash': '1918b1d25886b7598d9803dfbf06e51a14085b34',
#          'property': 'P1706',
#          'snaktype': 'value'},
#         {'datatype': 'wikibase-item',
#          'datavalue': {'type': 'wikibase-entityid',
#           'value': {'entity-type': 'item',
#            'id': 'Q184563',
#            'numeric-id': 184563}},
#          'hash': '636031cba693ad99e90303ac79a123d3c7580b36',
#          'property': 'P1706',
#          'snaktype': 'value'}],
#        'P2121': [{'datatype': 'quantity',
#          'datavalue': {'type': 'quantity',
#           'value': {'amount': '+94000',
#            'unit': 'http://www.wikidata.org/entity/Q122922'}},
#          'hash': 'fb44a7e2f897e3b4a031d8cfbb238e25025bcd86',
#          'property': 'P2121',
#          'snaktype': 'value'}],
#        'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1965-00-00T00:00:00Z',
#            'timezone': 0}},
#          'hash': '90900fad3e35a8dc48def62576233086e867b9be',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585', 'P1706', 'P2121'],
#       'rank': 'normal',
#       'references': [{'hash': '6841fc79fb2dfc9176ac99485d599f69979a9cd1',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'http://www.nobelprize.org/nobel_prizes/physics/laureates/1965/'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']},
#        {'hash': '2aadacb799507856faaf0815929ae9a0041615fb',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'https://www.nobelprize.org/nobel_prizes/about/amounts/'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'},
#      {'id': 'Q39246$e39f6325-4c1c-4a65-f1ec-557955cca675',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q1351451',
#          'numeric-id': 1351451}},
#        'property': 'P166',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1972-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': '97106a9f7cb898425acf6093a3d6c35cb3807791',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$37BE0942-38D4-46CF-9E98-A90F7C5995F5',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q7031462',
#          'numeric-id': 7031462}},
#        'property': 'P166',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$72d88ee9-43db-6f85-5a20-986eac0f3261',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q577432',
#          'numeric-id': 577432}},
#        'property': 'P166',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1954-00-00T00:00:00Z',
#            'timezone': 0}},
#          'hash': '12b9fd469993f71b3af92619cc1a44aef6b1dda7',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'type': 'statement'},
#      {'id': 'Q39246$F1BCC748-983C-464B-ACFB-CF742C474C33',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q14906020',
#          'numeric-id': 14906020}},
#        'property': 'P166',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 11,
#            'time': '+1965-04-08T00:00:00Z',
#            'timezone': 0}},
#          'hash': 'c2eb9af66e12c2ed8207ab4fb159eac4e5f615d5',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'references': [{'hash': 'c38df46df156eb368f474536e46447f00daabff8',
#         'snaks': {'P854': [{'datatype': 'url',
#            'datavalue': {'type': 'string',
#             'value': 'https://docs.google.com/spreadsheets/d/1RVVZY00MZNrK2YCTTzVrbTFH2t3RxoAZah128gQR-NM'},
#            'property': 'P854',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P854']}],
#       'type': 'statement'},
#      {'id': 'Q39246$E38947D5-D910-4467-AC44-C6A9E406C37E',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q737051',
#          'numeric-id': 737051}},
#        'property': 'P166',
#        'snaktype': 'value'},
#       'qualifiers': {'P585': [{'datatype': 'time',
#          'datavalue': {'type': 'time',
#           'value': {'after': 0,
#            'before': 0,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#            'precision': 9,
#            'time': '+1979-01-01T00:00:00Z',
#            'timezone': 0}},
#          'hash': '276024b79a62832b77b02a497e1a5d81c5c43cf3',
#          'property': 'P585',
#          'snaktype': 'value'}]},
#       'qualifiers-order': ['P585'],
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P1741': [{'id': 'Q39246$1283E8AB-9236-4F9C-991B-0F8FE56FAA4D',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '98617'},
#        'property': 'P1741',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P18': [{'id': 'q39246$A1ADD6B5-BA3B-4C52-85CA-4C99254A5056',
#       'mainsnak': {'datatype': 'commonsMedia',
#        'datavalue': {'type': 'string',
#         'value': 'RichardFeynman-PaineMansionWoods1984 copyrightTamikoThiel bw.jpg'},
#        'property': 'P18',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'd5847b9b6032aa8b13dae3c2dfd9ed5d114d21b3',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q11920',
#              'numeric-id': 11920}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P184': [{'id': 'Q39246$444122B6-1519-4CB2-BA4D-C9368A221F67',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q202631',
#          'numeric-id': 202631}},
#        'property': 'P184',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'id': 'Q328', 'numeric-id': 328}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P185': [{'id': 'Q39246$F8F035D3-D0C1-4CB3-8099-826750F7770D',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q547674',
#          'numeric-id': 547674}},
#        'property': 'P185',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'a29a646602abf65105ed0f39a44231c962ece9ee',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q177837',
#              'numeric-id': 177837}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P19': [{'id': 'Q39246$20e9473c-49d8-d6a8-7a55-4eb67199e95c',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q18424', 'numeric-id': 18424}},
#        'property': 'P19',
#        'snaktype': 'value'},
#       'rank': 'preferred',
#       'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item', 'id': 'Q328', 'numeric-id': 328}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']}],
#       'type': 'statement'}],
#     'P1953': [{'id': 'Q39246$1354EA21-D6B1-46B6-8240-37B3ACB52609',
#       'mainsnak': {'datatype': 'external-id',
#        'datavalue': {'type': 'string', 'value': '1736716'},
#        'property': 'P1953',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'b2e93db8744c6c00360db0868706706c3d951d92',
#         'snaks': {'P248': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q14005',
#              'numeric-id': 14005}},
#            'property': 'P248',
#            'snaktype': 'value'}],
#          'P813': [{'datatype': 'time',
#            'datavalue': {'type': 'time',
#             'value': {'after': 0,
#              'before': 0,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#              'precision': 11,
#              'time': '+2015-07-27T00:00:00Z',
#              'timezone': 0}},
#            'property': 'P813',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P248', 'P813']}],
#       'type': 'statement'}],
#     'P20': [{'id': 'q39246$42AB3BA7-F2FE-4A58-985A-88F98612E5D2',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item', 'id': 'Q65', 'numeric-id': 65}},
#        'property': 'P20',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q48183',
#              'numeric-id': 48183}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']},
#        {'hash': '503c8b8879ebe3e0e1614b921627708c0b8228ca',
#         'snaks': {'P248': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q36578',
#              'numeric-id': 36578}},
#            'property': 'P248',
#            'snaktype': 'value'}],
#          'P813': [{'datatype': 'time',
#            'datavalue': {'type': 'time',
#             'value': {'after': 0,
#              'before': 0,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#              'precision': 11,
#              'time': '+2014-12-30T00:00:00Z',
#              'timezone': 0}},
#            'property': 'P813',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P248', 'P813']}],
#       'type': 'statement'}],
#     'P2021': [{'id': 'Q39246$EAD549DA-11C0-4722-AD0B-4792F4B7F5E8',
#       'mainsnak': {'datatype': 'quantity',
#        'datavalue': {'type': 'quantity',
#         'value': {'amount': '+3',
#          'lowerBound': '+3',
#          'unit': '1',
#          'upperBound': '+3'}},
#        'property': 'P2021',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'type': 'statement'}],
#     'P21': [{'id': 'q39246$D0E22D09-196D-436D-B315-B678CA96A693',
#       'mainsnak': {'datatype': 'wikibase-item',
#        'datavalue': {'type': 'wikibase-entityid',
#         'value': {'entity-type': 'item',
#          'id': 'Q6581097',
#          'numeric-id': 6581097}},
#        'property': 'P21',
#        'snaktype': 'value'},
#       'rank': 'normal',
#       'references': [{'hash': 'bd49d3e4f67bc460ce7a06b6ac3027347cf5ee55',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q169514',
#              'numeric-id': 169514}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']},
#        {'hash': '759b2a264fff886006b6f49c3ef2f1acbfd1cef0',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q54919',
#              'numeric-id': 54919}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']},
#        {'hash': 'd5847b9b6032aa8b13dae3c2dfd9ed5d114d21b3',
#         'snaks': {'P143': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q11920',
#              'numeric-id': 11920}},
#            'property': 'P143',
#            'snaktype': 'value'}]},
#         'snaks-order': ['P143']},
#        {'hash': 'abc9457dcf728dd069b8ed5b2e1a86035cf2b679',
#         'snaks': {'P248': [{'datatype': 'wikibase-item',
#            'datavalue': {'type': 'wikibase-entityid',
#             'value': {'entity-type': 'item',
#              'id': 'Q36578',
#              'numeric-id': 36578}},
#            'property': 'P248',
# ...
#    'id': 'Q39246',
#    'labels': {'af': {'language': 'af', 'value': 'Richard Feynman'},
#     'am': {'language': 'am', 'value': 'ሪቻርድ ፋይንማን'},
#     'ar': {'language': 'ar', 'value': 'ريتشارد فاينمان'},
#     'as': {'language': 'as', 'value': 'ৰিচাৰ্ড ফাইনমেন'},
#     'ast': {'language': 'ast', 'value': 'Richard Feynman'},
#     'az': {'language': 'az', 'value': 'Riçard Feynman'},
#     'azb': {'language': 'azb', 'value': 'ریچارد فاینمن'},
#     'be': {'language': 'be', 'value': 'Рычард Філіпс Фейнман'},
#     'bg': {'language': 'bg', 'value': 'Ричард Файнман'},
#     'bn': {'language': 'bn', 'value': 'রিচার্ড ফাইনম্যান'},
#     'bs': {'language': 'bs', 'value': 'Richard Feynman'},
#     'ca': {'language': 'ca', 'value': 'Richard Feynman'},
#     'ckb': {'language': 'ckb', 'value': 'svae'},
#     'cs': {'language': 'cs', 'value': 'Richard Feynman'},
#     'cy': {'language': 'cy', 'value': 'Richard Feynman'},
#     'da': {'language': 'da', 'value': 'Richard Feynman'},
#     'de': {'language': 'de', 'value': 'Richard Feynman'},
#     'el': {'language': 'el', 'value': 'Ρίτσαρντ Φίλλιπς Φάινμαν'},
#     'en': {'language': 'en', 'value': 'Richard Feynman'},
#     'eo': {'language': 'eo', 'value': 'Richard Feynman'},
#     'es': {'language': 'es', 'value': 'Richard Feynman'},
#     'et': {'language': 'et', 'value': 'Richard Feynman'},
#     'eu': {'language': 'eu', 'value': 'Richard Feynman'},
#     'fa': {'language': 'fa', 'value': 'ریچارد فاینمن'},
#     'fi': {'language': 'fi', 'value': 'Richard Feynman'},
#     'fr': {'language': 'fr', 'value': 'Richard Feynman'},
#     'ga': {'language': 'ga', 'value': 'Richard Feynman'},
#     'gl': {'language': 'gl', 'value': 'Richard Feynman'},
#     'he': {'language': 'he', 'value': "ריצ'רד פיינמן"},
#     'hi': {'language': 'hi', 'value': 'रिचर्ड फिलिप्स फाइनमेन'},
#     'hr': {'language': 'hr', 'value': 'Richard Feynman'},
#     'ht': {'language': 'ht', 'value': 'Richard Feynman'},
#     'hu': {'language': 'hu', 'value': 'Richard Feynman'},
#     'hy': {'language': 'hy', 'value': 'Ռիչարդ Ֆեյնման'},
#     'id': {'language': 'id', 'value': 'Richard Feynman'},
#     'io': {'language': 'io', 'value': 'Richard Feynman'},
#     'is': {'language': 'is', 'value': 'Richard Feynman'},
#     'it': {'language': 'it', 'value': 'Richard Feynman'},
#     'ja': {'language': 'ja', 'value': 'リチャード・P・ファインマン'},
#     'jv': {'language': 'jv', 'value': 'Richard Feynman'},
#     'ka': {'language': 'ka', 'value': 'რიჩარდ ფეინმანი'},
#     'kk': {'language': 'kk', 'value': 'Ричард Филипс Фейнман'},
#     'ko': {'language': 'ko', 'value': '리처드 파인만'},
#     'ku': {'language': 'ku', 'value': 'Richard Feynman'},
#     'la': {'language': 'la', 'value': 'Ricardus Feynman'},
#     'lad': {'language': 'lad', 'value': 'Richard Feynman'},
#     'li': {'language': 'li', 'value': 'Richard Feynman'},
#     'lt': {'language': 'lt', 'value': 'Richard Feynman'},
#     'lv': {'language': 'lv', 'value': 'Ričards Fainmens'},
#     'mg': {'language': 'mg', 'value': 'Richard Feynman'},
#     'mk': {'language': 'mk', 'value': 'Ричард Фајнман'},
#     'ml': {'language': 'ml', 'value': 'റിച്ചാർഡ് ഫെയ്ൻമാൻ'},
#     'mr': {'language': 'mr', 'value': 'रिचर्ड फाइनमन'},
#     'ms': {'language': 'ms', 'value': 'Richard Feynman'},
#     'nan': {'language': 'nan', 'value': 'Richard Feynman'},
#     'nb': {'language': 'nb', 'value': 'Richard Feynman'},
#     'nds': {'language': 'nds', 'value': 'Richard Feynman'},
#     'new': {'language': 'new', 'value': 'रिचार्ड फेञम्यान'},
#     'nl': {'language': 'nl', 'value': 'Richard Feynman'},
#     'nn': {'language': 'nn', 'value': 'Richard Feynman'},
#     'oc': {'language': 'oc', 'value': 'Richard Feynman'},
#     'pam': {'language': 'pam', 'value': 'Richard Feynman'},
#     'pl': {'language': 'pl', 'value': 'Richard Feynman'},
#     'pms': {'language': 'pms', 'value': 'Richard Feynman'},
#     'pnb': {'language': 'pnb', 'value': 'رچرڈ فائنمین'},
#     'pt': {'language': 'pt', 'value': 'Richard Feynman'},
#     'pt-br': {'language': 'pt-br', 'value': 'Richard Feynman'},
#     'ro': {'language': 'ro', 'value': 'Richard Feynman'},
#     'ru': {'language': 'ru', 'value': 'Ричард Филлипс Фейнман'},
#     'rue': {'language': 'rue', 'value': 'Річард Фейнман'},
#     'sa': {'language': 'sa', 'value': 'रिचार्ड फैनमन'},
#     'sco': {'language': 'sco', 'value': 'Richard Feynman'},
#     'sh': {'language': 'sh', 'value': 'Richard Feynman'},
#     'sk': {'language': 'sk', 'value': 'Richard Feynman'},
#     'sl': {'language': 'sl', 'value': 'Richard Phillips Feynman'},
#     'sq': {'language': 'sq', 'value': 'Richard Feynman'},
#     'sr': {'language': 'sr', 'value': 'Ричард Филип Фајнман'},
#     'sv': {'language': 'sv', 'value': 'Richard Feynman'},
#     'sw': {'language': 'sw', 'value': 'Richard Feynman'},
#     'ta': {'language': 'ta', 'value': 'ரிச்சர்டு ஃபெயின்மான்'},
#     'tg': {'language': 'tg', 'value': 'Ричард Фейнман'},
#     'th': {'language': 'th', 'value': 'ริชาร์ด ไฟน์แมน'},
#     'tl': {'language': 'tl', 'value': 'Richard Feynman'},
#     'tr': {'language': 'tr', 'value': 'Richard Feynman'},
#     'uk': {'language': 'uk', 'value': 'Річард Філіпс Фейнман'},
#     'ur': {'language': 'ur', 'value': 'رچرڈ فلپ فے مین'},
#     'vi': {'language': 'vi', 'value': 'Richard Feynman'},
#     'war': {'language': 'war', 'value': 'Richard Feynman'},
#     'xmf': {'language': 'xmf', 'value': 'რიჩარდ ფეინმანი'},
#     'yo': {'language': 'yo', 'value': 'Richard Feynman'},
#     'yue': {'language': 'yue', 'value': '理察費曼'},
#     'zh': {'language': 'zh', 'value': '理查德·費曼'}},
#    'lastrevid': 537785543,
#    'modified': '2017-08-14T16:23:44Z',
#    'ns': 0,
#    'pageid': 41693,
#    'sitelinks': {'afwiki': {'badges': [],
#      'site': 'afwiki',
#      'title': 'Richard Feynman'},
#     'amwiki': {'badges': [], 'site': 'amwiki', 'title': 'ሪቻርድ ፋይንማን'},
#     'arwiki': {'badges': [], 'site': 'arwiki', 'title': 'ريتشارد فاينمان'},
#     'arwikiquote': {'badges': [],
#      'site': 'arwikiquote',
#      'title': 'ريتشارد فاينمان'},
#     'astwiki': {'badges': [], 'site': 'astwiki', 'title': 'Richard Feynman'},
#     'aswiki': {'badges': [], 'site': 'aswiki', 'title': 'ৰিচাৰ্ড ফাইনমেন'},
#     'azbwiki': {'badges': [], 'site': 'azbwiki', 'title': 'ریچارد فاینمن'},
#     'azwiki': {'badges': [], 'site': 'azwiki', 'title': 'Riçard Feynman'},
#     'bewiki': {'badges': [],
#      'site': 'bewiki',
#      'title': 'Рычард Філіпс Фейнман'},
#     'bgwiki': {'badges': [], 'site': 'bgwiki', 'title': 'Ричард Файнман'},
#     'bgwikiquote': {'badges': [],
#      'site': 'bgwikiquote',
#      'title': 'Ричард Файнман'},
#     'bnwiki': {'badges': [], 'site': 'bnwiki', 'title': 'রিচার্ড ফাইনম্যান'},
#     'bswiki': {'badges': [], 'site': 'bswiki', 'title': 'Richard Feynman'},
#     'cawiki': {'badges': [], 'site': 'cawiki', 'title': 'Richard Feynman'},
#     'cawikiquote': {'badges': [],
#      'site': 'cawikiquote',
#      'title': 'Richard Feynman'},
#     'ckbwiki': {'badges': [], 'site': 'ckbwiki', 'title': 'ڕیچارد فاینمان'},
#     'commonswiki': {'badges': [],
#      'site': 'commonswiki',
#      'title': 'Richard Feynman'},
#     'cswiki': {'badges': [], 'site': 'cswiki', 'title': 'Richard Feynman'},
#     'cswikiquote': {'badges': [],
#      'site': 'cswikiquote',
#      'title': 'Richard Feynman'},
#     'cywiki': {'badges': [], 'site': 'cywiki', 'title': 'Richard Feynman'},
#     'dawiki': {'badges': [], 'site': 'dawiki', 'title': 'Richard Feynman'},
#     'dawikiquote': {'badges': [],
#      'site': 'dawikiquote',
#      'title': 'Richard Feynman'},
#     'dewiki': {'badges': [], 'site': 'dewiki', 'title': 'Richard Feynman'},
#     'dewikiquote': {'badges': [],
#      'site': 'dewikiquote',
#      'title': 'Richard Feynman'},
#     'elwiki': {'badges': [],
#      'site': 'elwiki',
#      'title': 'Ρίτσαρντ Φίλλιπς Φάινμαν'},
#     'enwiki': {'badges': ['Q17437796'],
#      'site': 'enwiki',
#      'title': 'Richard Feynman'},
#     'enwikiquote': {'badges': [],
#      'site': 'enwikiquote',
#      'title': 'Richard Feynman'},
#     'eowiki': {'badges': [], 'site': 'eowiki', 'title': 'Richard Feynman'},
#     'eowikiquote': {'badges': [],
#      'site': 'eowikiquote',
#      'title': 'Richard Feynman'},
#     'eswiki': {'badges': [], 'site': 'eswiki', 'title': 'Richard Feynman'},
#     'eswikiquote': {'badges': [],
#      'site': 'eswikiquote',
#      'title': 'Richard Feynman'},
#     'etwiki': {'badges': [], 'site': 'etwiki', 'title': 'Richard Feynman'},
#     'euwiki': {'badges': [], 'site': 'euwiki', 'title': 'Richard Feynman'},
#     'fawiki': {'badges': [], 'site': 'fawiki', 'title': 'ریچارد فاینمن'},
#     'fawikiquote': {'badges': [],
#      'site': 'fawikiquote',
#      'title': 'ریچارد فاینمن'},
#     'fiwiki': {'badges': [], 'site': 'fiwiki', 'title': 'Richard Feynman'},
#     'fiwikiquote': {'badges': [],
#      'site': 'fiwikiquote',
#      'title': 'Richard Feynman'},
#     'frwiki': {'badges': [], 'site': 'frwiki', 'title': 'Richard Feynman'},
#     'frwikiquote': {'badges': [],
#      'site': 'frwikiquote',
#      'title': 'Richard Feynman'},
#     'gawiki': {'badges': [], 'site': 'gawiki', 'title': 'Richard Feynman'},
#     'glwiki': {'badges': [], 'site': 'glwiki', 'title': 'Richard Feynman'},
#     'glwikiquote': {'badges': [],
#      'site': 'glwikiquote',
#      'title': 'Richard Feynman'},
#     'hewiki': {'badges': [], 'site': 'hewiki', 'title': "ריצ'רד פיינמן"},
#     'hewikiquote': {'badges': [],
#      'site': 'hewikiquote',
#      'title': "ריצ'רד פיינמן"},
#     'hiwiki': {'badges': [],
#      'site': 'hiwiki',
#      'title': 'रिचर्ड फिलिप्स फाइनमेन'},
#     'hrwiki': {'badges': [], 'site': 'hrwiki', 'title': 'Richard Feynman'},
#     'htwiki': {'badges': [], 'site': 'htwiki', 'title': 'Richard Feynman'},
#     'huwiki': {'badges': [], 'site': 'huwiki', 'title': 'Richard Feynman'},
#     'huwikiquote': {'badges': [],
#      'site': 'huwikiquote',
#      'title': 'Richard Feynman'},
#     'hywiki': {'badges': [], 'site': 'hywiki', 'title': 'Ռիչարդ Ֆեյնման'},
#     'hywikiquote': {'badges': [],
#      'site': 'hywikiquote',
#      'title': 'Ռիչարդ Ֆայնման'},
#     'idwiki': {'badges': [], 'site': 'idwiki', 'title': 'Richard Feynman'},
#     'idwikiquote': {'badges': [],
#      'site': 'idwikiquote',
#      'title': 'Richard Feynman'},
#     'iowiki': {'badges': [], 'site': 'iowiki', 'title': 'Richard Feynman'},
#     'iswiki': {'badges': [], 'site': 'iswiki', 'title': 'Richard Feynman'},
#     'itwiki': {'badges': [], 'site': 'itwiki', 'title': 'Richard Feynman'},
#     'itwikiquote': {'badges': [],
#      'site': 'itwikiquote',
#      'title': 'Richard Feynman'},
#     'jawiki': {'badges': [], 'site': 'jawiki', 'title': 'リチャード・P・ファインマン'},
#     'jvwiki': {'badges': [], 'site': 'jvwiki', 'title': 'Richard Feynman'},
#     'kawiki': {'badges': [], 'site': 'kawiki', 'title': 'რიჩარდ ფეინმანი'},
#     'kkwiki': {'badges': [],
#      'site': 'kkwiki',
#      'title': 'Ричард Филипс Фейнман'},
#     'kowiki': {'badges': [], 'site': 'kowiki', 'title': '리처드 파인만'},
#     'kowikiquote': {'badges': [], 'site': 'kowikiquote', 'title': '리처드 파인만'},
#     'kuwiki': {'badges': [], 'site': 'kuwiki', 'title': 'Richard Feynman'},
#     'ladwiki': {'badges': [], 'site': 'ladwiki', 'title': 'Richard Feynman'},
#     'lawiki': {'badges': [], 'site': 'lawiki', 'title': 'Ricardus Feynman'},
#     'liwikiquote': {'badges': [],
#      'site': 'liwikiquote',
#      'title': 'Richard Feynman'},
#     'ltwiki': {'badges': [], 'site': 'ltwiki', 'title': 'Richard Feynman'},
#     'ltwikiquote': {'badges': [],
#      'site': 'ltwikiquote',
#      'title': 'Ričardas Fainmanas'},
#     'lvwiki': {'badges': [], 'site': 'lvwiki', 'title': 'Ričards Fainmens'},
#     'mgwiki': {'badges': [], 'site': 'mgwiki', 'title': 'Richard Feynman'},
#     'mkwiki': {'badges': [], 'site': 'mkwiki', 'title': 'Ричард Фајнман'},
#     'mlwiki': {'badges': [], 'site': 'mlwiki', 'title': 'റിച്ചാർഡ് ഫെയ്ൻമാൻ'},
#     'mrwiki': {'badges': [], 'site': 'mrwiki', 'title': 'रिचर्ड फाइनमन'},
#     'mswiki': {'badges': [], 'site': 'mswiki', 'title': 'Richard Feynman'},
#     'newwiki': {'badges': [], 'site': 'newwiki', 'title': 'रिचार्ड फेञम्यान'},
#     'nlwiki': {'badges': [], 'site': 'nlwiki', 'title': 'Richard Feynman'},
#     'nlwikiquote': {'badges': [],
#      'site': 'nlwikiquote',
#      'title': 'Richard Feynman'},
#     'nnwiki': {'badges': [], 'site': 'nnwiki', 'title': 'Richard Feynman'},
#     'nnwikiquote': {'badges': [],
#      'site': 'nnwikiquote',
#      'title': 'Richard Feynman'},
#     'nowiki': {'badges': [], 'site': 'nowiki', 'title': 'Richard Feynman'},
#     'ocwiki': {'badges': [], 'site': 'ocwiki', 'title': 'Richard Feynman'},
#     'pamwiki': {'badges': [], 'site': 'pamwiki', 'title': 'Richard Feynman'},
#     'plwiki': {'badges': [], 'site': 'plwiki', 'title': 'Richard Feynman'},
#     'plwikiquote': {'badges': [],
#      'site': 'plwikiquote',
#      'title': 'Richard Feynman'},
#     'pmswiki': {'badges': [], 'site': 'pmswiki', 'title': 'Richard Feynman'},
#     'pnbwiki': {'badges': [], 'site': 'pnbwiki', 'title': 'رچرڈ فائنمین'},
#     'ptwiki': {'badges': [], 'site': 'ptwiki', 'title': 'Richard Feynman'},
#     'ptwikiquote': {'badges': [],
#      'site': 'ptwikiquote',
#      'title': 'Richard Feynman'},
#     'rowiki': {'badges': [], 'site': 'rowiki', 'title': 'Richard Feynman'},
#     'rowikiquote': {'badges': [],
#      'site': 'rowikiquote',
#      'title': 'Richard Feynman'},
#     'ruewiki': {'badges': [], 'site': 'ruewiki', 'title': 'Річард Фейнман'},
#     'ruwiki': {'badges': [],
#      'site': 'ruwiki',
#      'title': 'Фейнман, Ричард Филлипс'},
#     'ruwikiquote': {'badges': [],
#      'site': 'ruwikiquote',
#      'title': 'Ричард Фейнман'},
#     'sawiki': {'badges': [], 'site': 'sawiki', 'title': 'रिचार्ड फैनमन'},
#     'scowiki': {'badges': [], 'site': 'scowiki', 'title': 'Richard Feynman'},
#     'shwiki': {'badges': [], 'site': 'shwiki', 'title': 'Richard Feynman'},
#     'simplewiki': {'badges': [],
#      'site': 'simplewiki',
#      'title': 'Richard Feynman'},
#     'simplewikiquote': {'badges': [],
#      'site': 'simplewikiquote',
#      'title': 'Richard Feynman'},
#     'skwiki': {'badges': [], 'site': 'skwiki', 'title': 'Richard Feynman'},
#     'skwikiquote': {'badges': [],
#      'site': 'skwikiquote',
#      'title': 'Richard Feynman'},
#     'slwiki': {'badges': [],
#      'site': 'slwiki',
#      'title': 'Richard Phillips Feynman'},
#     'slwikiquote': {'badges': [],
#      'site': 'slwikiquote',
#      'title': 'Richard Feynman'},
#     'sqwiki': {'badges': [], 'site': 'sqwiki', 'title': 'Richard Feynman'},
#     'srwiki': {'badges': [], 'site': 'srwiki', 'title': 'Ричард Фајнман'},
#     'srwikiquote': {'badges': [],
#      'site': 'srwikiquote',
#      'title': 'Ричард Фајнман'},
#     'svwiki': {'badges': [], 'site': 'svwiki', 'title': 'Richard Feynman'},
#     'swwiki': {'badges': [], 'site': 'swwiki', 'title': 'Richard Feynman'},
#     'tawiki': {'badges': [],
#      'site': 'tawiki',
#      'title': 'ரிச்சர்டு பெயின்மான்'},
#     'tawikiquote': {'badges': [],
#      'site': 'tawikiquote',
#      'title': 'ரிச்சர்டு ஃபெயின்மான்'},
#     'tgwiki': {'badges': [], 'site': 'tgwiki', 'title': 'Ричард Фейнман'},
#     'thwiki': {'badges': [], 'site': 'thwiki', 'title': 'ริชาร์ด ไฟน์แมน'},
#     'tlwiki': {'badges': [], 'site': 'tlwiki', 'title': 'Richard Feynman'},
#     'trwiki': {'badges': [], 'site': 'trwiki', 'title': 'Richard Feynman'},
#     'trwikiquote': {'badges': [],
#      'site': 'trwikiquote',
#      'title': 'Richard Feynman'},
#     'ukwiki': {'badges': [],
#      'site': 'ukwiki',
#      'title': 'Річард Філіпс Фейнман'},
#     'urwiki': {'badges': [], 'site': 'urwiki', 'title': 'رچرڈ فلپ فائنمین'},
#     'viwiki': {'badges': [], 'site': 'viwiki', 'title': 'Richard Feynman'},
#     'warwiki': {'badges': [], 'site': 'warwiki', 'title': 'Richard Feynman'},
#     'xmfwiki': {'badges': [], 'site': 'xmfwiki', 'title': 'რიჩარდ ფეინმანი'},
#     'yowiki': {'badges': [], 'site': 'yowiki', 'title': 'Richard Feynman'},
#     'zh_min_nanwiki': {'badges': [],
#      'site': 'zh_min_nanwiki',
#      'title': 'Richard Feynman'},
#     'zh_yuewiki': {'badges': [], 'site': 'zh_yuewiki', 'title': '理察費曼'},
#     'zhwiki': {'badges': [], 'site': 'zhwiki', 'title': '理查德·費曼'},
#     'zhwikiquote': {'badges': [], 'site': 'zhwikiquote', 'title': '費曼'}},
#    'title': 'Q39246',
#    'type': 'item'}},
#  'success': 1}

# %% [markdown]
# ## Using my old repo

# %%
base_url = "https://en.wikipedia.org/w/api.php"

# %%
action = "?action=mobileview"
parameters = "&format=json&prop=sections&sections=all"
page = "&page="

# %%
richard_feynman_url = base_url + action + parameters + page + 'Richard_Feynman'

# %%
response_rich_f = requests.get(richard_feynman_url)

# %%
response_rich_f.status_code
# Out:
# 200

# %%
response_rich_f.json()
# Out:
# {'mobileview': {'sections': [{'id': 0},
#    {'id': 1, 'line': 'Early life', 'toclevel': 1},
#    {'id': 2, 'line': 'Education', 'toclevel': 1},
#    {'id': 3, 'line': 'Manhattan Project', 'toclevel': 1},
#    {'id': 4, 'line': 'Cornell', 'toclevel': 1},
#    {'id': 5, 'line': 'Caltech years', 'toclevel': 1},
#    {'id': 6, 'line': 'Personal and political life', 'toclevel': 2},
#    {'id': 7, 'line': 'Physics', 'toclevel': 2},
#    {'id': 8, 'line': 'Pedagogy', 'toclevel': 2},
#    {'id': 9, 'line': "<i>Surely You're Joking Mr. Feynman</i>", 'toclevel': 2},
#    {'id': 10, 'line': 'Challenger disaster', 'toclevel': 2},
#    {'id': 11, 'line': 'Recognition and awards', 'toclevel': 2},
#    {'id': 12, 'line': 'Death', 'toclevel': 1},
#    {'id': 13, 'line': 'Popular legacy', 'toclevel': 1},
#    {'id': 14, 'line': 'Bibliography', 'toclevel': 1},
#    {'id': 15, 'line': 'Selected scientific works', 'toclevel': 2},
#    {'id': 16, 'line': 'Textbooks and lecture notes', 'toclevel': 2},
#    {'id': 17, 'line': 'Popular works', 'toclevel': 2},
#    {'id': 18, 'line': 'Audio and video recordings', 'toclevel': 2},
#    {'id': 19, 'line': 'Notes', 'references': '', 'toclevel': 1},
#    {'id': 20, 'line': 'References', 'toclevel': 1},
#    {'id': 21, 'line': 'Further reading', 'toclevel': 1},
#    {'id': 22, 'line': 'Articles', 'toclevel': 2},
#    {'id': 23, 'line': 'Books', 'toclevel': 2},
#    {'id': 24, 'line': 'Films and plays', 'toclevel': 2},
#    {'id': 25, 'line': 'External links', 'toclevel': 1}]}}

# %%
richard_f_page_headings = response_rich_f.json()

# %%
richard_f_page_headings['mobileview'].keys()
# Out:
# dict_keys(['sections'])

# %% [markdown]
# ## Experimentation with Wikipedia

# %%
base_url = "https://en.wikipedia.org/w/api.php"

# %%
action = "?action=query"
# parameters = "&format=json&generator=links&gpllimit=500&redirects=true"
parameters = "&prop=info|revisions&list=backlinks|embeddedin|allimages&meta=userinfo"
page = "&page="

# %%
ml_url = base_url  + action + parameters + page + 'Category:Machine_learning'

# %%
ml_url
# Out:
# 'https://en.wikipedia.org/w/api.php?action=query&prop=info|revisions&list=backlinks|embeddedin|allimages&meta=userinfo&page=Category:Machine_learning'

# %%
response_ml = requests.get(ml_url)

# %%
response_ml.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-196-ae0b141cc018> in <module>()
# ----> 1 response_ml.json()
#
# /opt/conda/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# /opt/conda/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /opt/conda/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /opt/conda/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
ml_url = 'https://en.wikipedia.org/wiki/Category:Machine_learning'

# %%
response_ml = requests.get(ml_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response_ml.text)
inner_ul = soup.find('ul', class_='innerUl')
inner_items = [li.text.strip() for li in inner_ul.ul.find_all('li')]

outer_ul_text = soup.ul.span.text.strip()
inner_ul_text = inner_ul.span.text.strip()

result = {outer_ul_text: {inner_ul_text: inner_items}}
print (result)
# Out:
# /opt/conda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /opt/conda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html5lib")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-205-80ac6aee0a81> in <module>()
#       1 soup = BeautifulSoup(response_ml.text)
#       2 inner_ul = soup.find('ul', class_='innerUl')
# ----> 3 inner_items = [li.text.strip() for li in inner_ul.ul.find_all('li')]
#       4
#       5 outer_ul_text = soup.ul.span.text.strip()
#
# AttributeError: 'NoneType' object has no attribute 'ul'
