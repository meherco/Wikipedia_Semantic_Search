# %%
# Use first query to capture relevant data on Machine Learning and Business software

# %%
# Grab all first and second layer articles for both

# %%
# Seperate the Category from not category on the first pass

# %% [markdown]
# Define library for connecting to database

# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Using cached psycopg2-2.7.3.1-cp36-cp36m-manylinux1_x86_64.whl
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.7.3.1

# %%
import psycopg2 as pg2
from pandas import DataFrame
from psycopg2.extras import RealDictCursor
import pandas as pd
def connect_to_db():
    con = pg2.connect(host='postgres', 
                      dbname='postgres', 
                      user='postgres')
    cur = con.cursor(cursor_factory=RealDictCursor)
    return con, cur
    
def query_to_dictionary(query, fetch_res=True):
    con, cur = connect_to_db()
    cur.execute(query)
    if fetch_res:
        results = cur.fetchall()
    else:
        results = None
    con.close()
    return results

def query_to_dataframe(query):
    return DataFrame(query_to_dictionary(query))

# %% [markdown]
# First grab all the articles from Machine learning and business software with one layer down

# %%
# !pip install wikipedia --quiet
import re
import requests
import pandas as pd
import wikipedia

# %%
def generate_category(category):
    '''
    format a category for insertion in to a wikipedia api call
    '''
    category = re.sub('\s','+',category)
    return category

# %%
def generate_query(category):
    '''
    Format an api call for requests
    '''
    query = '''https://en.wikipedia.org/w/api.php?
            action=query&
            format=json&
            list=categorymembers&
            cmtitle=Category:{}&
            cmlimit=max
            '''.format(generate_category(category))
    query = re.sub('\s','',query)
    return query

# %%
generate_query('Machine learning')
# Out:
# 'https://en.wikipedia.org/w/api.php?action=query&format=json&list=categorymembers&cmtitle=Category:Machine+learning&cmlimit=max'

# %%
def execute_category_query(category):
    '''
    Executes a category query and returns a DataFrame of the category members
    '''
    
    r = requests.get(generate_query(category))
    response = r.json()
    
    return pd.DataFrame(response['query']['categorymembers'])

# %%
execute_category_query('Machine learning')
# Out:
#      ns    pageid                                              title
# 0     2  54972729  User:CustIntelMngt/sandbox/Customer Intelligen...
# 1     0  43385931                                   Data exploration
# 2     0  49082762     List of datasets for machine learning research
# 3     0    233488                                   Machine learning
# 4     0  53587467                        Outline of machine learning
# 5     0   3771060                                   Accuracy paradox
# 6     0  43808044                              Action model learning
# 7     0  28801798                 Active learning (machine learning)
# 8     0  45049676                       Adversarial machine learning
# 9     0  52642349                                               AIVA
# 10    0  30511763                                               AIXI
# 11    0  50773876                                Algorithm Selection
# 12    0  20890511                              Algorithmic inference
# 13    0  49242352                                            AlphaGo
# 14    0  19463198                            Apprenticeship learning
# 15    0  14003441                                 Bag-of-words model
# 16    0  31877832                                          Ball tree
# 17    0   9732182                                          Base rate
# 18    0  35867897   Bayesian interpretation of kernel regularization
# 19    0  40973765                              Bayesian optimization
# 20    0  50211107                    Bayesian structural time series
# 21    0  40678189                             Bias–variance tradeoff
# 22    0  55075082                                              BigDL
# 23    0    205393                              Binary classification
# 24    0  50646178                                      Bing Predicts
# 25    0   1191936                                    Bongard problem
# 26    0  44439173                                Bradley–Terry model
# 27    0  53631046                                   Caffe (software)
# 28    0  39182554                          Catastrophic interference
# 29    0   8964665                                   Category utility
# ..   ..       ...                                                ...
# 200  14  33547387                  Category:Applied machine learning
# 201  14  42936114                Category:Artificial neural networks
# 202  14   1718975                         Category:Bayesian networks
# 203  14   1991254                 Category:Classification algorithms
# 204  14  22532673                          Category:Cluster analysis
# 205  14  34310097             Category:Computational learning theory
# 206  14  12932492       Category:Artificial intelligence conferences
# 207  14  33542714  Category:Data mining and machine learning soft...
# 208  14  42320378              Category:Datasets in machine learning
# 209  14  29549713                       Category:Dimension reduction
# 210  14   3985352                         Category:Ensemble learning
# 211  14    754055                   Category:Evolutionary algorithms
# 212  14   3061615                       Category:Genetic programming
# 213  14  29003796               Category:Inductive logic programming
# 214  14  12535256       Category:Kernel methods for machine learning
# 215  14  20924581                    Category:Latent variable models
# 216  14  19314112               Category:Learning in computer vision
# 217  14  36407925                         Category:Log-linear models
# 218  14  28004586                            Category:Loss functions
# 219  14  33547228               Category:Machine learning algorithms
# 220  14  44943481                   Category:Machine learning portal
# 221  14  47991509                     Category:Machine learning task
# 222  14  24059390                             Category:Markov models
# 223  14   3832584              Category:Machine learning researchers
# 224  14  52763829                   Category:Semisupervised learning
# 225  14  11737376   Category:Statistical natural language processing
# 226  14  40149461                     Category:Structured prediction
# 227  14  52763867                       Category:Supervised learning
# 228  14  31176997                   Category:Support vector machines
# 229  14  52763828                     Category:Unsupervised learning
#
# [230 rows x 3 columns]

# %%
def update_table(table_name, col_values):
    query = '''
        BEGIN;
        INSERT INTO {} VALUES ({});
        COMMIT;
        '''.format(table_name, format_data_for_query(col_values))
    query_to_dictionary(query,fetch_res=False)

# %%
# def write_to_dbpage(title,text):
#     con, cur = connect_to_db()
#     query = """
#     BEGIN; 
#     INSERT INTO page (title, text) VALUES ('{}','{}'); 
#     COMMIT;
#     """.format(title,text)
#     cur.execute(query)

# %%
def put_data_to_dbpage(category):
    category_df = execute_category_query(category)    
    category_mask = category_df['title'].str.contains('Category:')
    pages_in_category = category_df[~category_mask]['title'].tolist()
    
    for page in pages_in_category:
        ctext = get_clean_text(page)
        ctitle = cleaner(page)
        write_to_dbpage(ctitle, ctext)

# %%
put_data_to_dbpage('Machine learning')

# %%
query = 'SELECT * FROM page'
query_to_dataframe(query)
# Out:
#      page_id                                               text  \
# 0          1   this is not a wikipedia article it is an indi...
# 1          2   this article has multiple issues please help ...
# 2          3   machine learning and data mining problems cla...
# 3          4  for the journal see machine learning journal m...
# 4          5  the following outline is provided as an overvi...
# 5          6  the accuracy paradox for predictive analytics ...
# 6          7   machine learning and data mining problems cla...
# 7          8  this article is about a machine learning metho...
# 8          9  adversarial machine learning is a research fie...
# 9         10   aiva nationality luxembourgish style classica...
# 10        11   this article has multiple issues please help ...
# 11        12   this article is an orphan as no other article...
# 12        13  algorithmic inference gathers new developments...
# 13        14   alphago logo alphago is a narrow ai computer ...
# 14        15  apprenticeship learning or apprenticeship via ...
# 15        16  for bag of words model in computer vision see ...
# 16        17  this article is about the binary tree variant ...
# 17        18   this article needs additional citations for v...
# 18        19   this article provides insufficient context fo...
# 19        20  bayesian optimization is a sequential design s...
# 20        21   this article includes a list of references bu...
# 21        22   this article needs additional citations for v...
# 22        23   this article needs additional citations for v...
# 23        24   the topic of this article may not meet wikipe...
# 24        25   an example bongard problem the common factor ...
# 25        26  the bradley terry model is a probability model...
# 26        27   caffe original author s yangqing jia develope...
# 27        28   this article has multiple issues please help ...
# 28        29  category utility is a measure of category good...
# 29        30  the center for biological computational learni...
# ..       ...                                                ...
# 168      166  semantic folding theory describes a procedure ...
# 169      167   machine learning and data mining problems cla...
# 170      168   this article needs additional citations for v...
# 171      169  similarity learning is an area of supervised m...
# 172      170   skymind type privately held industry analytic...
# 173      171   this article has multiple issues please help ...
# 174      172   machine learning and data mining problems cla...
# 175      173  spike and slab regression is a bayesian variab...
# 176      174  stability also known as algorithmic stability ...
# 177      178  the stochastic block model is a generative mod...
# 178      179  for other uses see minimisation structural ris...
# 179      180   this article is an orphan as no other article...
# 180      181   this article has multiple issues please help ...
# 181      182  see also unsupervised learning machine learnin...
# 182      183   this article has multiple issues please help ...
# 183      184  this page is a timeline of machine learning ma...
# 184      185   this article includes a list of references re...
# 185      186  transfer learning or inductive transfer is a r...
# 186      187   this article is an orphan as no other article...
# 187      188   this article needs additional citations for v...
# 188      189  in computer science uncertain data is data tha...
# 189      190  for other uses see uniform convergence uniform...
# 190      191   this article is an orphan as no other article...
# 191      192   this article has multiple issues please help ...
# 192      193  user behaviour analytics uba as defined by gar...
# 193      194  redirect to test set validation set to a secti...
# 194      195   machine learning and data mining problems cla...
# 195      196   version space for a rectangle hypothesis lang...
# 196      197   vgg image annotator original author s abhishe...
# 197      198   machine learning and data mining problems cla...
#
#                                                  title
# 0    user custintelmngt sandbox customer intelligen...
# 1                                     data exploration
# 2       list of datasets for machine learning research
# 3                                     machine learning
# 4                          outline of machine learning
# 5                                     accuracy paradox
# 6                                action model learning
# 7                    active learning machine learning
# 8                         adversarial machine learning
# 9                                                 aiva
# 10                                                aixi
# 11                                 algorithm selection
# 12                               algorithmic inference
# 13                                             alphago
# 14                             apprenticeship learning
# 15                                  bag of words model
# 16                                           ball tree
# 17                                           base rate
# 18    bayesian interpretation of kernel regularization
# 19                               bayesian optimization
# 20                     bayesian structural time series
# 21                              bias variance tradeoff
# 22                               binary classification
# 23                                       bing predicts
# 24                                     bongard problem
# 25                                 bradley terry model
# 26                                     caffe software
# 27                           catastrophic interference
# 28                                    category utility
# 29                                           cbcl mit
# ..                                                 ...
# 168                                   semantic folding
# 169                           semi supervised learning
# 170                                  sequence labeling
# 171                                similarity learning
# 172                                            skymind
# 173          solomonoffs theory of inductive inference
# 174                         sparse dictionary learning
# 175                  spike and slab variable selection
# 176                         stability learning theory
# 177                             stochastic block model
# 178                       structural risk minimization
# 179                 structured sparsity regularization
# 180                              subclass reachability
# 181                                supervised learning
# 182                                           test set
# 183                       timeline of machine learning
# 184                     transduction machine learning
# 185                                  transfer learning
# 186                             trax image recognition
# 187                              ugly duckling theorem
# 188                                     uncertain data
# 189                 uniform convergence in probability
# 190                      universal portfolio algorithm
# 191                              unsupervised learning
# 192                            user behavior analytics
# 193                                     validation set
# 194                         vanishing gradient problem
# 195                             version space learning
# 196                                vgg image annotator
# 197                                    word NUMBER vec
#
# [198 rows x 3 columns]

# %%
connect_to_db()
query = 'SELECT * FROM page'
query_to_dataframe(query)
query = 'SELECT * FROM category'
query_to_dataframe(query)
query = 'SELECT * FROM page_category'
query_to_dataframe(query)

# %%
def get_all_pages_first_level(category):
    category_df = execute_category_query(category)
    pages_list = []
    category_mask = category_df['title'].str.contains('Category:')
 
    #Grab all articles (titles that do not contain 'Category:') and append them to list
    pages_df = category_df[~category_mask]
    pages_list.append(pages_df)

    #For the sub-categories, call the second level function to grab those articles
    categories = category_df[category_mask]['title']\
                        .str.replace('Category:','').tolist()
    
    for categori in categories:
        category_df = execute_category_query(categori)
        category_mask = category_df['title'].str.contains('Category:')
 
        #Grab all articles (titles that do not contain 'Category:') and append them to list
        pages_df = category_df[~category_mask]
        pages_list.append(pages_df)    
    
    return pages_list

# %%
machine_learning_list = get_all_pages_first_level('Machine learning')

# %%
len(machine_learning_list)
# Out:
# 31

# %%
business_soft_list = get_all_pages_first_level('Business software')

# %%
len(business_soft_list)
# Out:
# 33

# %% [markdown]
# _____________

# %%
from bs4 import BeautifulSoup

# %%
def generate_parse(category):
    '''
    Format for api call to grab an article's text
    '''
    query = '''https://en.wikipedia.org/w/api.php?
            action=parse&
            format=json&
            page={}
            '''.format(generate_category(category))
    query = re.sub('\s','',query)
    return query

# %%
def execute_category_parse(category):
    '''
    Executes a category parse and returns a DataFrame of the category members
    '''    
    r = requests.get(generate_parse(category))
    response = r.json()
    return response

# %%
def json_to_html(category):
    article_html = execute_category_parse(category)['parse']['text']['*'] \
        if not execute_category_parse(category).get('error') else ''
    return article_html

# %%
def cleaner(message):
    message = re.sub('\.+', ' ', message)
    message = re.sub('\'+', '', message)
    message = re.sub('[^a-z0-9 ]',' ', message.lower())
    message = re.sub('\d+',' NUMBER ',message)
    message = re.sub('\s+',' ',message)
    return message

# %%
def make_beautiful_html(category):
    article_html = json_to_html(category)
    soup = BeautifulSoup(article_html,'html.parser')
    article_text = soup.get_text()
    return article_text

# %%
def get_clean_text(category):
    article_text = make_beautiful_html(category)
    return cleaner(article_text)

# %% [markdown]
# ____________________

# %% [markdown]
# Grab all data from each categories using the methods defined above...

# %%
len(machine_learning_list)

# %% [markdown]
# Combine the data into a single DataFrame

# %%
df_tot = pd.DataFrame()
for df in machine_learning_list:
    df_tot = pd.concat([df_tot, df],axis=0)
    df_tot['Category'] = 'Machine Learning'
for df in business_soft_list:
    df_tot = pd.concat([df_tot, df],axis=0)
    df_tot['Category'] = 'Business Software'

# %%
df_tot

# %%
df_tot['text'] = df_tot['title'].apply(lambda x: get_clean_text(x))
